# %% [markdown]
# 1. Obter o Conjunto de Dados (CSV)
#
# Rodar jupyter notebook e criar arquivo do projeto.
#
# 2. Pré-processamento dos Dados:
#
# Importe as bibliotecas:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Carregue o conjunto de dados:

# %%
dados = pd.read_csv("credito.csv")

# %% [markdown]
# Analise os dados:

# %%
dados.head()  # Visualize as primeiras linhas do DataFrame
dados.describe()  # Obtenha estatísticas descritivas das variáveis
dados.info()  # Verifique tipos de dados e informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             5 non-null      int64
#  1   idade          5 non-null      int64
#  2   renda          5 non-null      int64
#  3   divida         5 non-null      int64
#  4   inadimplencia  5 non-null      int64
#  5   aprovacao      5 non-null      int64
# dtypes: int64(6)
# memory usage: 372.0 bytes

# %% [markdown]
# Verifique a presença de valores ausentes:

# %%
dados.isnull().sum()  # Quantidade de valores ausentes por variável
# Out:
# id               0
# idade            0
# renda            0
# divida           0
# inadimplencia    0
# aprovacao        0
# dtype: int64

# %% [markdown]
# Trate os valores ausentes (opcional):
#
# Exclusão: Remova linhas com valores ausentes (não recomendado para conjuntos de dados pequenos).
# Imputação: Preencha os valores ausentes com estimativas (média, mediana, etc.).
# Analise a distribuição das variáveis numéricas:

# %%
import matplotlib.pyplot as plt

dados.hist(figsize=(10, 6))
plt.show()

# %% [markdown]
# Normalização das variáveis numéricas:

# %%
#scaler = StandardScaler()

#X = dados[["idade", "renda", "divida"]]  # Selecionando variáveis numéricas
#X_scaled = scaler.fit_transform(X)  # Normalização

#dados["Idade_Normalizada"] = X_scaled[:, 0]
#dados["Renda_Normalizada"] = X_scaled[:, 1]
#dados["Divida_Normalizada"] = X_scaled[:, 2]

# %% [markdown]
# Codificação de variáveis categóricas:

# %%
#from sklearn.preprocessing import OneHotEncoder
#encoder = OneHotEncoder()

#historico_codificado = encoder.fit_transform(dados[["inadimplencia"]])
#dados_com_codificacao = pd.concat([dados, pd.DataFrame(historico_codificado, columns=["Historico_Bom", "Historico_Ruim"])], axis=1)

# %% [markdown]
# Seleção das variáveis:

# %%
X = dados[["idade", "renda", "divida", "inadimplencia"]]
y = dados["aprovacao"]

# %% [markdown]
# 3. Treinamento e Avaliação do Modelo:
#
# Divida o conjunto de dados em treino e teste:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# Crie o modelo de regressão logística:

# %%
modelo = LogisticRegression()

# %% [markdown]
# Treine o modelo:

# %%
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Faça previsões no conjunto de teste:

# %%
y_pred = modelo.predict(X_test)

# %% [markdown]
# Avalie a performance do modelo:

# %%
print("Precisão:", accuracy_score(y_test, y_pred))
print("Precisão:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-Score:", f1_score(y_test, y_pred))
# Out:
# Precisão: 0.5
# Precisão: 0.0
# Recall: 0.0
# F1-Score: 0.0
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
